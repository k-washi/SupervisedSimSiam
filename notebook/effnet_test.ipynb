# %% [markdown]
# # Efficient Net の確認を行う

# %%
# %cd ../../SupervisedSimSiam/
# %pwd
# Out:
# /Users/washizakikai/dev/practice/git/SupervisedSimSiam
# '/Users/washizakikai/dev/practice/git/SupervisedSimSiam'

# %%
from torchsummary import summary

# %%
# %load_ext autoreload
# %autoreload 2

from modules.models.efficient_net import SqueezeExcitation
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
seblock = SqueezeExcitation(10, 5)

# %%
summary(seblock, (10, 255, 255))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#  AdaptiveAvgPool2d-1             [-1, 10, 1, 1]               0
#             Conv2d-2              [-1, 5, 1, 1]              55
#              Swish-3              [-1, 5, 1, 1]               0
#             Conv2d-4             [-1, 10, 1, 1]              60
# ...
# Total params: 115
# Trainable params: 115
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 2.48
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 2.48
# ----------------------------------------------------------------

# %% [markdown]
# # Effnet_b0の確認

# %%
from modules.models.efficient_net import efficientnet_b0

# %%
model = efficientnet_b0(input_ch=3, num_classes=5)

# %%
summary(model, (3, 250, 250))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 32, 124, 124]             864
#        BatchNorm2d-2         [-1, 32, 124, 124]              64
#             ConvBN-3         [-1, 32, 124, 124]               0
#              Swish-4         [-1, 32, 124, 124]               0
#             Conv2d-5         [-1, 32, 124, 124]             288
#        BatchNorm2d-6         [-1, 32, 124, 124]              64
#             ConvBN-7         [-1, 32, 124, 124]               0
#              Swish-8         [-1, 32, 124, 124]               0
#  AdaptiveAvgPool2d-9             [-1, 32, 1, 1]               0
#            Conv2d-10              [-1, 8, 1, 1]             264
#             Swish-11              [-1, 8, 1, 1]               0
#            Conv2d-12             [-1, 32, 1, 1]             288
# SqueezeExcitation-13         [-1, 32, 124, 124]               0
# ...

# %%
model = efficientnet_b0(input_ch=3, num_classes=0)
summary(model, (3, 250, 250))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 32, 124, 124]             864
#        BatchNorm2d-2         [-1, 32, 124, 124]              64
#             ConvBN-3         [-1, 32, 124, 124]               0
#              Swish-4         [-1, 32, 124, 124]               0
#             Conv2d-5         [-1, 32, 124, 124]             288
#        BatchNorm2d-6         [-1, 32, 124, 124]              64
#             ConvBN-7         [-1, 32, 124, 124]               0
#              Swish-8         [-1, 32, 124, 124]               0
#  AdaptiveAvgPool2d-9             [-1, 32, 1, 1]               0
#            Conv2d-10              [-1, 8, 1, 1]             264
#             Swish-11              [-1, 8, 1, 1]               0
#            Conv2d-12             [-1, 32, 1, 1]             288
# SqueezeExcitation-13         [-1, 32, 124, 124]               0
# ...

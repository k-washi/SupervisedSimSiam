# %% [markdown]
# # データローダの確認をする

# %%
# %cd ../../SupervisedSimSiam/
# %pwd
# Out:
# [Errno 2] No such file or directory: '../../SupervisedSimSiam/'
# /Users/washizakikai/dev/practice/git/SupervisedSimSiam
# '/Users/washizakikai/dev/practice/git/SupervisedSimSiam'

# %%
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # 設定値の読み込み

# %%
# %load_ext autoreload
# %autoreload 2
from utils.config import Config
cnf = Config.get_cnf("conf")
print(cnf)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'food101': {'dataset_dir': 'dataset/food-101/images', 'train_json': 'dataset/food-101/meta/train.json', 'test_json': 'dataset/food-101/meta/test.json', 'img_ext': '.jpg'}, 'dataloader': {'batch_size': 20, 'num_workers': 0, 'pin_memory': True, 'target_size_h': 256, 'target_size_w': 256, 'val_rate': 0.2}}

# %% [markdown]
# # データローダの確認

# %%
# %load_ext autoreload
# %autoreload 2

from modules.dataset.food101.dataloader import create_dataloader
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_dataloader, val_dataloader, test_dataloader = create_dataloader(cnf)
# Out:
# {"name": "Supervised Sim Siam", "level": "INFO", "time": "2021-02-05 21:19:37", "filename": "dataloader.py", "function": "create_dataloader", "message": "create dataset loader: batch_size:20, num_workers: 0, pin_memory: True"}
# {"name": "Supervised Sim Siam", "level": "INFO", "time": "2021-02-05 21:19:38", "filename": "dataloader.py", "function": "create_dataloader", "message": "train dataloader: 3030"}
# {"name": "Supervised Sim Siam", "level": "INFO", "time": "2021-02-05 21:19:38", "filename": "dataloader.py", "function": "create_dataloader", "message": "val dataloader: 758"}
# {"name": "Supervised Sim Siam", "level": "INFO", "time": "2021-02-05 21:19:38", "filename": "dataloader.py", "function": "create_dataloader", "message": "test dataloader: 1263"}

# %%
for input, label in train_dataloader:
    batch_length = input.size()[0]
    plt.figure(figsize=(20., 10.))
    for ind in range(batch_length):
        img = input[ind].permute(1,2,0).cpu().detach().numpy()
        
        plt.subplot(1, batch_length, ind+1)
        plt.imshow(img)
        plt.axis("off")
    plt.show()
    break
